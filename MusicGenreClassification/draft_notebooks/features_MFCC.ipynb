# %%
import numpy as np
import librosa as rosa
import librosa.display as display
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
import features

# %%
y, sr = rosa.load(rosa.util.example_audio_file())
y = y[:661500]

# %%
# %%time
mfccs = features.get_MFCC(y)
print(mfccs.shape)
# Out:
# (20, 3007)
# CPU times: user 304 ms, sys: 0 ns, total: 304 ms
# Wall time: 31.1 ms

# %%
rosa.display.specshow(mfccs, x_axis='time')
plt.title('MFCC')
plt.colorbar()
plt.tight_layout()
