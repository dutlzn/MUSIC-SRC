# %%
import sys
import os.path as osp

sys.argv[1:] = []
sys.path.append(osp.abspath('..'))


import numpy as np
import librosa as rosa
import librosa.display as display
import matplotlib.pyplot as plt

from datasets.features import get_melspectrogram

# %%
x, sr = rosa.load('/Users/youchen/Downloads/GTZAN/genres/blues/blues.00000.au')
print(x.shape)
# Out:
# (661794,)

# %%
y = get_melspectrogram(x[:66560])
print(y.shape)
plt.figure(figsize=(8, 4))
display.specshow(y, sr=sr, hop_length=1024, x_axis='time', y_axis='mel')
# Out:
# (128, 64)

# %%
y = get_melspectrogram(x)
print(y.shape)
plt.figure(figsize=(8, 4))
display.specshow(y, sr=sr, hop_length=1024, x_axis='time', y_axis='mel')
# Out:
# (128, 645)
